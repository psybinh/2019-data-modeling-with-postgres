# %% [markdown]
# author: Phung Binh </br>
# email: psybinh@gmail.com

# %%
DATA_FOLDER = '/home/binhps/de-udacity/data_modeling_with_postgres/MillionSongSample/'
LOG_DATA_FOLDER = DATA_FOLDER + 'log_data/'
SONG_DATA_FOLDER = DATA_FOLDER + 'song_data/'

# %%
import os
import pandas as pd

# log data
def all_files(_dir):
    for root, dirs, files in os.walk(_dir):
        for file in files:
            path = os.path.join(root, file)
            yield path

# %%
for file_path in all_files(LOG_DATA_FOLDER):
    file = pd.read_json(file_path, lines=True)
    
print(file.columns)
print(file.info())
# Out:
# Index(['artist', 'auth', 'firstName', 'gender', 'itemInSession', 'lastName',
#        'length', 'level', 'location', 'method', 'page', 'registration',
#        'sessionId', 'song', 'status', 'ts', 'userAgent', 'userId'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 18 columns):
# artist           41 non-null object
# auth             59 non-null object
# firstName        58 non-null object
# gender           58 non-null object
# itemInSession    59 non-null int64
# lastName         58 non-null object
# length           41 non-null float64
# level            59 non-null object
# location         58 non-null object
# method           59 non-null object
# page             59 non-null object
# registration     58 non-null float64
# sessionId        59 non-null int64
# song             41 non-null object
# status           59 non-null int64
# ts               59 non-null int64
# userAgent        58 non-null object
# userId           59 non-null object
# dtypes: float64(2), int64(4), object(12)
# memory usage: 8.4+ KB
# None

# %%
file.head()
# Out:
#                        artist       auth firstName gender  itemInSession  \
# 0             matchbox twenty  Logged In    Jayden      F              0
# 1  The Lonely Island / T-Pain  Logged In    Jayden      F              1
# 2                        None  Logged In    Jayden      F              2
# 3                        None  Logged In    Jayden      F              3
# 4                        None  Logged In    Jayden      F              4
#
#   lastName     length level                     location method  \
# 0    Duffy  177.65832  free  Seattle-Tacoma-Bellevue, WA    PUT
# 1    Duffy  156.23791  free  Seattle-Tacoma-Bellevue, WA    PUT
# 2    Duffy        NaN  free  Seattle-Tacoma-Bellevue, WA    GET
# 3    Duffy        NaN  free  Seattle-Tacoma-Bellevue, WA    GET
# 4    Duffy        NaN  free  Seattle-Tacoma-Bellevue, WA    PUT
#
#             page  registration  sessionId                song  status  \
# 0       NextSong  1.540146e+12        846  Argue (LP Version)     200
# 1       NextSong  1.540146e+12        846       I'm On A Boat     200
# 2           Home  1.540146e+12        846                None     200
# 3       Settings  1.540146e+12        846                None     200
# 4  Save Settings  1.540146e+12        846                None     307
#
#               ts                                          userAgent userId
# 0  1543109954796  "Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like...     76
# 1  1543110131796  "Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like...     76
# 2  1543110132796  "Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like...     76
# 3  1543110168796  "Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like...     76
# 4  1543110169796  "Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like...     76

# %%
file.apply(lambda row: print(row, str(row)), axis=1)
# Out:
# artist                                             matchbox twenty
# auth                                                     Logged In
# firstName                                                   Jayden
# gender                                                           F
# itemInSession                                                    0
# lastName                                                     Duffy
# length                                                     177.658
# level                                                         free
# location                               Seattle-Tacoma-Bellevue, WA
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54015e+12
# sessionId                                                      846
# song                                            Argue (LP Version)
# status                                                         200
# ts                                                   1543109954796
# userAgent        "Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like...
# userId                                                          76
# Name: 0, dtype: object artist                                             matchbox twenty
# auth                                                     Logged In
# firstName                                                   Jayden
# gender                                                           F
# itemInSession                                                    0
# lastName                                                     Duffy
# length                                                     177.658
# level                                                         free
# location                               Seattle-Tacoma-Bellevue, WA
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54015e+12
# sessionId                                                      846
# song                                            Argue (LP Version)
# status                                                         200
# ts                                                   1543109954796
# userAgent        "Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like...
# userId                                                          76
# Name: 0, dtype: object
# artist                                  The Lonely Island / T-Pain
# auth                                                     Logged In
# firstName                                                   Jayden
# gender                                                           F
# itemInSession                                                    1
# lastName                                                     Duffy
# length                                                     156.238
# level                                                         free
# location                               Seattle-Tacoma-Bellevue, WA
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54015e+12
# sessionId                                                      846
# song                                                 I'm On A Boat
# status                                                         200
# ts                                                   1543110131796
# userAgent        "Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like...
# userId                                                          76
# Name: 1, dtype: object artist                                  The Lonely Island / T-Pain
# auth                                                     Logged In
# firstName                                                   Jayden
# gender                                                           F
# itemInSession                                                    1
# lastName                                                     Duffy
# length                                                     156.238
# level                                                         free
# location                               Seattle-Tacoma-Bellevue, WA
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54015e+12
# sessionId                                                      846
# song                                                 I'm On A Boat
# status                                                         200
# ts                                                   1543110131796
# userAgent        "Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like...
# userId                                                          76
# Name: 1, dtype: object
# artist                                                        None
# auth                                                     Logged In
# firstName                                                   Jayden
# gender                                                           F
# itemInSession                                                    2
# lastName                                                     Duffy
# length                                                         NaN
# level                                                         free
# location                               Seattle-Tacoma-Bellevue, WA
# method                                                         GET
# page                                                          Home
# registration                                           1.54015e+12
# sessionId                                                      846
# song                                                          None
# status                                                         200
# ts                                                   1543110132796
# userAgent        "Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like...
# userId                                                          76
# Name: 2, dtype: object artist                                                        None
# auth                                                     Logged In
# firstName                                                   Jayden
# gender                                                           F
# itemInSession                                                    2
# lastName                                                     Duffy
# length                                                         NaN
# level                                                         free
# location                               Seattle-Tacoma-Bellevue, WA
# method                                                         GET
# page                                                          Home
# registration                                           1.54015e+12
# sessionId                                                      846
# song                                                          None
# status                                                         200
# ts                                                   1543110132796
# userAgent        "Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like...
# userId                                                          76
# Name: 2, dtype: object
# artist                                                        None
# auth                                                     Logged In
# firstName                                                   Jayden
# gender                                                           F
# itemInSession                                                    3
# lastName                                                     Duffy
# length                                                         NaN
# level                                                         free
# location                               Seattle-Tacoma-Bellevue, WA
# method                                                         GET
# page                                                      Settings
# registration                                           1.54015e+12
# sessionId                                                      846
# song                                                          None
# status                                                         200
# ts                                                   1543110168796
# userAgent        "Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like...
# userId                                                          76
# Name: 3, dtype: object artist                                                        None
# auth                                                     Logged In
# firstName                                                   Jayden
# gender                                                           F
# itemInSession                                                    3
# lastName                                                     Duffy
# length                                                         NaN
# level                                                         free
# location                               Seattle-Tacoma-Bellevue, WA
# method                                                         GET
# page                                                      Settings
# registration                                           1.54015e+12
# sessionId                                                      846
# song                                                          None
# status                                                         200
# ts                                                   1543110168796
# userAgent        "Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like...
# userId                                                          76
# Name: 3, dtype: object
# artist                                                        None
# auth                                                     Logged In
# firstName                                                   Jayden
# gender                                                           F
# itemInSession                                                    4
# lastName                                                     Duffy
# length                                                         NaN
# level                                                         free
# location                               Seattle-Tacoma-Bellevue, WA
# method                                                         PUT
# page                                                 Save Settings
# registration                                           1.54015e+12
# sessionId                                                      846
# song                                                          None
# status                                                         307
# ts                                                   1543110169796
# userAgent        "Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like...
# userId                                                          76
# Name: 4, dtype: object artist                                                        None
# auth                                                     Logged In
# firstName                                                   Jayden
# gender                                                           F
# itemInSession                                                    4
# lastName                                                     Duffy
# length                                                         NaN
# level                                                         free
# location                               Seattle-Tacoma-Bellevue, WA
# method                                                         PUT
# page                                                 Save Settings
# registration                                           1.54015e+12
# sessionId                                                      846
# song                                                          None
# status                                                         307
# ts                                                   1543110169796
# userAgent        "Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like...
# userId                                                          76
# Name: 4, dtype: object
# artist                                                  John Mayer
# auth                                                     Logged In
# firstName                                                    Wyatt
# gender                                                           M
# itemInSession                                                    0
# lastName                                                     Scott
# length                                                     275.278
# level                                                         free
# location                                 Eureka-Arcata-Fortuna, CA
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54087e+12
# sessionId                                                      856
# song                                 All We Ever Do Is Say Goodbye
# status                                                         200
# ts                                                   1543113347796
# userAgent        Mozilla/5.0 (Windows NT 6.1; WOW64; Trident/7....
# userId                                                           9
# Name: 5, dtype: object artist                                                  John Mayer
# auth                                                     Logged In
# firstName                                                    Wyatt
# gender                                                           M
# itemInSession                                                    0
# lastName                                                     Scott
# length                                                     275.278
# level                                                         free
# location                                 Eureka-Arcata-Fortuna, CA
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54087e+12
# sessionId                                                      856
# song                                 All We Ever Do Is Say Goodbye
# status                                                         200
# ts                                                   1543113347796
# userAgent        Mozilla/5.0 (Windows NT 6.1; WOW64; Trident/7....
# userId                                                           9
# Name: 5, dtype: object
# artist                                                        None
# auth                                                     Logged In
# firstName                                                    Wyatt
# gender                                                           M
# itemInSession                                                    1
# lastName                                                     Scott
# length                                                         NaN
# level                                                         free
# location                                 Eureka-Arcata-Fortuna, CA
# method                                                         GET
# page                                                          Home
# registration                                           1.54087e+12
# sessionId                                                      856
# song                                                          None
# status                                                         200
# ts                                                   1543113365796
# userAgent        Mozilla/5.0 (Windows NT 6.1; WOW64; Trident/7....
# userId                                                           9
# Name: 6, dtype: object artist                                                        None
# auth                                                     Logged In
# firstName                                                    Wyatt
# gender                                                           M
# itemInSession                                                    1
# lastName                                                     Scott
# length                                                         NaN
# level                                                         free
# location                                 Eureka-Arcata-Fortuna, CA
# method                                                         GET
# page                                                          Home
# registration                                           1.54087e+12
# sessionId                                                      856
# song                                                          None
# status                                                         200
# ts                                                   1543113365796
# userAgent        Mozilla/5.0 (Windows NT 6.1; WOW64; Trident/7....
# userId                                                           9
# Name: 6, dtype: object
# artist                                              10_000 Maniacs
# auth                                                     Logged In
# firstName                                                    Wyatt
# gender                                                           M
# itemInSession                                                    2
# lastName                                                     Scott
# length                                                     251.872
# level                                                         free
# location                                 Eureka-Arcata-Fortuna, CA
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54087e+12
# sessionId                                                      856
# song                                          Gun Shy (LP Version)
# status                                                         200
# ts                                                   1543113622796
# userAgent        Mozilla/5.0 (Windows NT 6.1; WOW64; Trident/7....
# userId                                                           9
# Name: 7, dtype: object artist                                              10_000 Maniacs
# auth                                                     Logged In
# firstName                                                    Wyatt
# gender                                                           M
# itemInSession                                                    2
# lastName                                                     Scott
# length                                                     251.872
# level                                                         free
# location                                 Eureka-Arcata-Fortuna, CA
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54087e+12
# sessionId                                                      856
# song                                          Gun Shy (LP Version)
# status                                                         200
# ts                                                   1543113622796
# userAgent        Mozilla/5.0 (Windows NT 6.1; WOW64; Trident/7....
# userId                                                           9
# Name: 7, dtype: object
# artist                                                 Leona Lewis
# auth                                                     Logged In
# firstName                                                    Chloe
# gender                                                           F
# itemInSession                                                    0
# lastName                                                    Cuevas
# length                                                     203.885
# level                                                         paid
# location                         San Francisco-Oakland-Hayward, CA
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54094e+12
# sessionId                                                      916
# song                                                    Forgive Me
# status                                                         200
# ts                                                   1543122348796
# userAgent        Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...
# userId                                                          49
# Name: 8, dtype: object artist                                                 Leona Lewis
# auth                                                     Logged In
# firstName                                                    Chloe
# gender                                                           F
# itemInSession                                                    0
# lastName                                                    Cuevas
# length                                                     203.885
# level                                                         paid
# location                         San Francisco-Oakland-Hayward, CA
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54094e+12
# sessionId                                                      916
# song                                                    Forgive Me
# status                                                         200
# ts                                                   1543122348796
# userAgent        Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...
# userId                                                          49
# Name: 8, dtype: object
# artist                                             Nine Inch Nails
# auth                                                     Logged In
# firstName                                                    Chloe
# gender                                                           F
# itemInSession                                                    1
# lastName                                                    Cuevas
# length                                                     277.838
# level                                                         paid
# location                         San Francisco-Oakland-Hayward, CA
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54094e+12
# sessionId                                                      916
# song                                                        La Mer
# status                                                         200
# ts                                                   1543122551796
# userAgent        Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...
# userId                                                          49
# Name: 9, dtype: object artist                                             Nine Inch Nails
# auth                                                     Logged In
# firstName                                                    Chloe
# gender                                                           F
# itemInSession                                                    1
# lastName                                                    Cuevas
# length                                                     277.838
# level                                                         paid
# location                         San Francisco-Oakland-Hayward, CA
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54094e+12
# sessionId                                                      916
# song                                                        La Mer
# status                                                         200
# ts                                                   1543122551796
# userAgent        Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...
# userId                                                          49
# Name: 9, dtype: object
# artist                                                  Audioslave
# auth                                                     Logged In
# firstName                                                    Chloe
# gender                                                           F
# itemInSession                                                    2
# lastName                                                    Cuevas
# length                                                     334.915
# level                                                         paid
# location                         San Francisco-Oakland-Hayward, CA
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54094e+12
# sessionId                                                      916
# song                                              I Am The Highway
# status                                                         200
# ts                                                   1543122828796
# userAgent        Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...
# userId                                                          49
# Name: 10, dtype: object artist                                                  Audioslave
# auth                                                     Logged In
# firstName                                                    Chloe
# gender                                                           F
# itemInSession                                                    2
# lastName                                                    Cuevas
# length                                                     334.915
# level                                                         paid
# location                         San Francisco-Oakland-Hayward, CA
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54094e+12
# sessionId                                                      916
# song                                              I Am The Highway
# status                                                         200
# ts                                                   1543122828796
# userAgent        Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...
# userId                                                          49
# Name: 10, dtype: object
# artist                                                    Kid Rock
# auth                                                     Logged In
# firstName                                                    Chloe
# gender                                                           F
# itemInSession                                                    3
# lastName                                                    Cuevas
# length                                                      296.96
# level                                                         paid
# location                         San Francisco-Oakland-Hayward, CA
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54094e+12
# sessionId                                                      916
# song                               All Summer Long (Album Version)
# status                                                         200
# ts                                                   1543123162796
# userAgent        Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...
# userId                                                          49
# Name: 11, dtype: object artist                                                    Kid Rock
# auth                                                     Logged In
# firstName                                                    Chloe
# gender                                                           F
# itemInSession                                                    3
# lastName                                                    Cuevas
# length                                                      296.96
# level                                                         paid
# location                         San Francisco-Oakland-Hayward, CA
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54094e+12
# sessionId                                                      916
# song                               All Summer Long (Album Version)
# status                                                         200
# ts                                                   1543123162796
# userAgent        Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...
# userId                                                          49
# Name: 11, dtype: object
# artist                                                    The Jets
# auth                                                     Logged In
# firstName                                                    Chloe
# gender                                                           F
# itemInSession                                                    4
# lastName                                                    Cuevas
# length                                                     220.891
# level                                                         paid
# location                         San Francisco-Oakland-Hayward, CA
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54094e+12
# sessionId                                                      916
# song                                                      I Do You
# status                                                         200
# ts                                                   1543123458796
# userAgent        Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...
# userId                                                          49
# Name: 12, dtype: object artist                                                    The Jets
# auth                                                     Logged In
# firstName                                                    Chloe
# gender                                                           F
# itemInSession                                                    4
# lastName                                                    Cuevas
# length                                                     220.891
# level                                                         paid
# location                         San Francisco-Oakland-Hayward, CA
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54094e+12
# sessionId                                                      916
# song                                                      I Do You
# status                                                         200
# ts                                                   1543123458796
# userAgent        Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...
# userId                                                          49
# Name: 12, dtype: object
# artist                                                 The Gerbils
# auth                                                     Logged In
# firstName                                                    Chloe
# gender                                                           F
# itemInSession                                                    5
# lastName                                                    Cuevas
# length                                                     27.0102
# level                                                         paid
# location                         San Francisco-Oakland-Hayward, CA
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54094e+12
# sessionId                                                      916
# song                                                         (iii)
# status                                                         200
# ts                                                   1543123678796
# userAgent        Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...
# userId                                                          49
# Name: 13, dtype: object artist                                                 The Gerbils
# auth                                                     Logged In
# firstName                                                    Chloe
# gender                                                           F
# itemInSession                                                    5
# lastName                                                    Cuevas
# length                                                     27.0102
# level                                                         paid
# location                         San Francisco-Oakland-Hayward, CA
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54094e+12
# sessionId                                                      916
# song                                                         (iii)
# status                                                         200
# ts                                                   1543123678796
# userAgent        Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...
# userId                                                          49
# Name: 13, dtype: object
# artist                  Damian Marley / Stephen Marley / Yami Bolo
# auth                                                     Logged In
# firstName                                                    Chloe
# gender                                                           F
# itemInSession                                                    6
# lastName                                                    Cuevas
# length                                                     304.692
# level                                                         paid
# location                         San Francisco-Oakland-Hayward, CA
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54094e+12
# sessionId                                                      916
# song                                               Still Searching
# status                                                         200
# ts                                                   1543123705796
# userAgent        Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...
# userId                                                          49
# Name: 14, dtype: object artist                  Damian Marley / Stephen Marley / Yami Bolo
# auth                                                     Logged In
# firstName                                                    Chloe
# gender                                                           F
# itemInSession                                                    6
# lastName                                                    Cuevas
# length                                                     304.692
# level                                                         paid
# location                         San Francisco-Oakland-Hayward, CA
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54094e+12
# sessionId                                                      916
# song                                               Still Searching
# status                                                         200
# ts                                                   1543123705796
# userAgent        Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...
# userId                                                          49
# Name: 14, dtype: object
# artist                                                        None
# auth                                                     Logged In
# firstName                                                    Chloe
# gender                                                           F
# itemInSession                                                    7
# lastName                                                    Cuevas
# length                                                         NaN
# level                                                         paid
# location                         San Francisco-Oakland-Hayward, CA
# method                                                         GET
# page                                                          Home
# registration                                           1.54094e+12
# sessionId                                                      916
# song                                                          None
# status                                                         200
# ts                                                   1543124166796
# userAgent        Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...
# userId                                                          49
# Name: 15, dtype: object artist                                                        None
# auth                                                     Logged In
# firstName                                                    Chloe
# gender                                                           F
# itemInSession                                                    7
# lastName                                                    Cuevas
# length                                                         NaN
# level                                                         paid
# location                         San Francisco-Oakland-Hayward, CA
# method                                                         GET
# page                                                          Home
# registration                                           1.54094e+12
# sessionId                                                      916
# song                                                          None
# status                                                         200
# ts                                                   1543124166796
# userAgent        Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...
# userId                                                          49
# Name: 15, dtype: object
# artist                                        The Bloody Beetroots
# auth                                                     Logged In
# firstName                                                    Chloe
# gender                                                           F
# itemInSession                                                    8
# lastName                                                    Cuevas
# length                                                     201.978
# level                                                         paid
# location                         San Francisco-Oakland-Hayward, CA
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54094e+12
# sessionId                                                      916
# song                                   Warp 1.9 (feat. Steve Aoki)
# status                                                         200
# ts                                                   1543124951796
# userAgent        Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...
# userId                                                          49
# Name: 16, dtype: object artist                                        The Bloody Beetroots
# auth                                                     Logged In
# firstName                                                    Chloe
# gender                                                           F
# itemInSession                                                    8
# lastName                                                    Cuevas
# length                                                     201.978
# level                                                         paid
# location                         San Francisco-Oakland-Hayward, CA
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54094e+12
# sessionId                                                      916
# song                                   Warp 1.9 (feat. Steve Aoki)
# status                                                         200
# ts                                                   1543124951796
# userAgent        Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...
# userId                                                          49
# Name: 16, dtype: object
# artist                                                        None
# auth                                                     Logged In
# firstName                                                    Chloe
# gender                                                           F
# itemInSession                                                    9
# lastName                                                    Cuevas
# length                                                         NaN
# level                                                         paid
# location                         San Francisco-Oakland-Hayward, CA
# method                                                         GET
# page                                                          Home
# registration                                           1.54094e+12
# sessionId                                                      916
# song                                                          None
# status                                                         200
# ts                                                   1543125120796
# userAgent        Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...
# userId                                                          49
# Name: 17, dtype: object artist                                                        None
# auth                                                     Logged In
# firstName                                                    Chloe
# gender                                                           F
# itemInSession                                                    9
# lastName                                                    Cuevas
# length                                                         NaN
# level                                                         paid
# location                         San Francisco-Oakland-Hayward, CA
# method                                                         GET
# page                                                          Home
# registration                                           1.54094e+12
# sessionId                                                      916
# song                                                          None
# status                                                         200
# ts                                                   1543125120796
# userAgent        Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...
# userId                                                          49
# Name: 17, dtype: object
# artist                                                The Specials
# auth                                                     Logged In
# firstName                                                    Chloe
# gender                                                           F
# itemInSession                                                   10
# lastName                                                    Cuevas
# length                                                     188.813
# level                                                         paid
# location                         San Francisco-Oakland-Hayward, CA
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54094e+12
# sessionId                                                      916
# song                                                      Rat Race
# status                                                         200
# ts                                                   1543125152796
# userAgent        Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...
# userId                                                          49
# Name: 18, dtype: object artist                                                The Specials
# auth                                                     Logged In
# firstName                                                    Chloe
# gender                                                           F
# itemInSession                                                   10
# lastName                                                    Cuevas
# length                                                     188.813
# level                                                         paid
# location                         San Francisco-Oakland-Hayward, CA
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54094e+12
# sessionId                                                      916
# song                                                      Rat Race
# status                                                         200
# ts                                                   1543125152796
# userAgent        Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...
# userId                                                          49
# Name: 18, dtype: object
# artist                                             The Lively Ones
# auth                                                     Logged In
# firstName                                                    Chloe
# gender                                                           F
# itemInSession                                                   11
# lastName                                                    Cuevas
# length                                                     142.524
# level                                                         paid
# location                         San Francisco-Oakland-Hayward, CA
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54094e+12
# sessionId                                                      916
# song                                Walkin' The Board (LP Version)
# status                                                         200
# ts                                                   1543125340796
# userAgent        Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...
# userId                                                          49
# ...
# method                                                         PUT
# page                                                        Logout
# registration                                           1.54079e+12
# sessionId                                                      915
# song                                                          None
# status                                                         307
# ts                                                   1543170975796
# userAgent        "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# userId                                                          80
# Name: 52, dtype: object artist                                                        None
# auth                                                     Logged In
# firstName                                                    Tegan
# gender                                                           F
# itemInSession                                                    6
# lastName                                                    Levine
# length                                                         NaN
# level                                                         paid
# location                               Portland-South Portland, ME
# method                                                         PUT
# page                                                        Logout
# registration                                           1.54079e+12
# sessionId                                                      915
# song                                                          None
# status                                                         307
# ts                                                   1543170975796
# userAgent        "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# userId                                                          80
# Name: 52, dtype: object
# artist                                                        None
# auth                                                     Logged In
# firstName                                                   Sylvie
# gender                                                           F
# itemInSession                                                    0
# lastName                                                      Cruz
# length                                                         NaN
# level                                                         free
# location              Washington-Arlington-Alexandria, DC-VA-MD-WV
# method                                                         GET
# page                                                          Home
# registration                                           1.54027e+12
# sessionId                                                      912
# song                                                          None
# status                                                         200
# ts                                                   1543170999796
# userAgent        "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# userId                                                          10
# Name: 53, dtype: object artist                                                        None
# auth                                                     Logged In
# firstName                                                   Sylvie
# gender                                                           F
# itemInSession                                                    0
# lastName                                                      Cruz
# length                                                         NaN
# level                                                         free
# location              Washington-Arlington-Alexandria, DC-VA-MD-WV
# method                                                         GET
# page                                                          Home
# registration                                           1.54027e+12
# sessionId                                                      912
# song                                                          None
# status                                                         200
# ts                                                   1543170999796
# userAgent        "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# userId                                                          10
# Name: 53, dtype: object
# artist                    None
# auth                Logged Out
# firstName                 None
# gender                    None
# itemInSession                7
# lastName                  None
# length                     NaN
# level                     paid
# location                  None
# method                     GET
# page                      Home
# registration               NaN
# sessionId                  915
# song                      None
# status                     200
# ts               1543171228796
# userAgent                 None
# userId
# Name: 54, dtype: object artist                    None
# auth                Logged Out
# firstName                 None
# gender                    None
# itemInSession                7
# lastName                  None
# length                     NaN
# level                     paid
# location                  None
# method                     GET
# page                      Home
# registration               NaN
# sessionId                  915
# song                      None
# status                     200
# ts               1543171228796
# userAgent                 None
# userId
# Name: 54, dtype: object
# artist                                                    Gondwana
# auth                                                     Logged In
# firstName                                                   Jordan
# gender                                                           F
# itemInSession                                                    0
# lastName                                                     Hicks
# length                                                     262.582
# level                                                         free
# location                                               Salinas, CA
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54001e+12
# sessionId                                                      814
# song                                                   Mi Princesa
# status                                                         200
# ts                                                   1543189690796
# userAgent        "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# userId                                                          37
# Name: 55, dtype: object artist                                                    Gondwana
# auth                                                     Logged In
# firstName                                                   Jordan
# gender                                                           F
# itemInSession                                                    0
# lastName                                                     Hicks
# length                                                     262.582
# level                                                         free
# location                                               Salinas, CA
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54001e+12
# sessionId                                                      814
# song                                                   Mi Princesa
# status                                                         200
# ts                                                   1543189690796
# userAgent        "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# userId                                                          37
# Name: 55, dtype: object
# artist                                                        None
# auth                                                     Logged In
# firstName                                                    Kevin
# gender                                                           M
# itemInSession                                                    0
# lastName                                                  Arellano
# length                                                         NaN
# level                                                         free
# location                                   Harrisburg-Carlisle, PA
# method                                                         GET
# page                                                          Home
# registration                                           1.54001e+12
# sessionId                                                      855
# song                                                          None
# status                                                         200
# ts                                                   1543189812796
# userAgent        "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# userId                                                          66
# Name: 56, dtype: object artist                                                        None
# auth                                                     Logged In
# firstName                                                    Kevin
# gender                                                           M
# itemInSession                                                    0
# lastName                                                  Arellano
# length                                                         NaN
# level                                                         free
# location                                   Harrisburg-Carlisle, PA
# method                                                         GET
# page                                                          Home
# registration                                           1.54001e+12
# sessionId                                                      855
# song                                                          None
# status                                                         200
# ts                                                   1543189812796
# userAgent        "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# userId                                                          66
# Name: 56, dtype: object
# artist                                             Ella Fitzgerald
# auth                                                     Logged In
# firstName                                                   Jordan
# gender                                                           F
# itemInSession                                                    1
# lastName                                                     Hicks
# length                                                     427.154
# level                                                         free
# location                                               Salinas, CA
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54001e+12
# sessionId                                                      814
# song             On Green Dolphin Street (Medley) (1999 Digital...
# status                                                         200
# ts                                                   1543189952796
# userAgent        "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# userId                                                          37
# Name: 57, dtype: object artist                                             Ella Fitzgerald
# auth                                                     Logged In
# firstName                                                   Jordan
# gender                                                           F
# itemInSession                                                    1
# lastName                                                     Hicks
# length                                                     427.154
# level                                                         free
# location                                               Salinas, CA
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54001e+12
# sessionId                                                      814
# song             On Green Dolphin Street (Medley) (1999 Digital...
# status                                                         200
# ts                                                   1543189952796
# userAgent        "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# userId                                                          37
# Name: 57, dtype: object
# artist                                Creedence Clearwater Revival
# auth                                                     Logged In
# firstName                                                   Jordan
# gender                                                           F
# itemInSession                                                    2
# lastName                                                     Hicks
# length                                                     184.738
# level                                                         free
# location                                               Salinas, CA
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54001e+12
# sessionId                                                      814
# song                                        Run Through The Jungle
# status                                                         200
# ts                                                   1543190379796
# userAgent        "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# userId                                                          37
# Name: 58, dtype: object artist                                Creedence Clearwater Revival
# auth                                                     Logged In
# firstName                                                   Jordan
# gender                                                           F
# itemInSession                                                    2
# lastName                                                     Hicks
# length                                                     184.738
# level                                                         free
# location                                               Salinas, CA
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54001e+12
# sessionId                                                      814
# song                                        Run Through The Jungle
# status                                                         200
# ts                                                   1543190379796
# userAgent        "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# userId                                                          37
# Name: 58, dtype: object
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None
# 5     None
# 6     None
# 7     None
# 8     None
# 9     None
# 10    None
# 11    None
# 12    None
# 13    None
# 14    None
# 15    None
# 16    None
# 17    None
# 18    None
# 19    None
# 20    None
# 21    None
# 22    None
# 23    None
# 24    None
# 25    None
# 26    None
# 27    None
# 28    None
# 29    None
# 30    None
# 31    None
# 32    None
# 33    None
# 34    None
# 35    None
# 36    None
# 37    None
# 38    None
# 39    None
# 40    None
# 41    None
# 42    None
# 43    None
# 44    None
# 45    None
# 46    None
# 47    None
# 48    None
# 49    None
# 50    None
# 51    None
# 52    None
# 53    None
# 54    None
# 55    None
# 56    None
# 57    None
# 58    None
# dtype: object

# %%
datetime = pd.to_datetime(file['ts'], unit='ms')
datetime.head()
# Out:
# 0   2018-11-25 01:39:14.796
# 1   2018-11-25 01:42:11.796
# 2   2018-11-25 01:42:12.796
# 3   2018-11-25 01:42:48.796
# 4   2018-11-25 01:42:49.796
# Name: ts, dtype: datetime64[ns]

# %%
a = datetime.apply(lambda row: print('--' + str(row)))
# Out:
# --2018-11-25 01:39:14.796000
# --2018-11-25 01:42:11.796000
# --2018-11-25 01:42:12.796000
# --2018-11-25 01:42:48.796000
# --2018-11-25 01:42:49.796000
# --2018-11-25 02:35:47.796000
# --2018-11-25 02:36:05.796000
# --2018-11-25 02:40:22.796000
# --2018-11-25 05:05:48.796000
# --2018-11-25 05:09:11.796000
# --2018-11-25 05:13:48.796000
# --2018-11-25 05:19:22.796000
# --2018-11-25 05:24:18.796000
# --2018-11-25 05:27:58.796000
# --2018-11-25 05:28:25.796000
# --2018-11-25 05:36:06.796000
# --2018-11-25 05:49:11.796000
# --2018-11-25 05:52:00.796000
# --2018-11-25 05:52:32.796000
# --2018-11-25 05:55:40.796000
# --2018-11-25 05:58:02.796000
# --2018-11-25 06:02:14.796000
# --2018-11-25 06:06:17.796000
# --2018-11-25 06:08:30.796000
# --2018-11-25 06:11:10.796000
# --2018-11-25 06:15:59.796000
# --2018-11-25 06:20:20.796000
# --2018-11-25 06:46:58.796000
# --2018-11-25 06:51:16.796000
# --2018-11-25 08:07:36.796000
# --2018-11-25 08:40:08.796000
# --2018-11-25 11:28:19.796000
# --2018-11-25 11:28:25.796000
# --2018-11-25 13:07:04.796000
# --2018-11-25 13:56:40.796000
# --2018-11-25 14:13:48.796000
# --2018-11-25 14:17:10.796000
# --2018-11-25 15:58:03.796000
# --2018-11-25 16:06:25.796000
# --2018-11-25 16:10:39.796000
# --2018-11-25 16:14:24.796000
# --2018-11-25 16:18:23.796000
# --2018-11-25 16:22:11.796000
# --2018-11-25 17:29:05.796000
# --2018-11-25 17:29:05.796000
# --2018-11-25 17:29:13.796000
# --2018-11-25 18:19:34.796000
# --2018-11-25 18:21:32.796000
# --2018-11-25 18:24:18.796000
# --2018-11-25 18:27:30.796000
# --2018-11-25 18:31:25.796000
# --2018-11-25 18:36:14.796000
# --2018-11-25 18:36:15.796000
# --2018-11-25 18:36:39.796000
# --2018-11-25 18:40:28.796000
# --2018-11-25 23:48:10.796000
# --2018-11-25 23:50:12.796000
# --2018-11-25 23:52:32.796000
# --2018-11-25 23:59:39.796000

# %%
for file_path in all_files(SONG_DATA_FOLDER):
    file = pd.read_json(file_path, lines=True)
    
print(file.columns)
print(file.info())
# Out:
# Index(['num_songs', 'artist_id', 'artist_latitude', 'artist_longitude',
#        'artist_location', 'artist_name', 'song_id', 'title', 'duration',
#        'year'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 10 columns):
# num_songs           1 non-null int64
# artist_id           1 non-null object
# artist_latitude     0 non-null float64
# artist_longitude    0 non-null float64
# artist_location     1 non-null object
# artist_name         1 non-null object
# song_id             1 non-null object
# title               1 non-null object
# duration            1 non-null float64
# year                1 non-null int64
# dtypes: float64(3), int64(2), object(5)
# memory usage: 208.0+ bytes
# None

# %%
file
# Out:
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  ARJIE2Y1187B994AB7              NaN               NaN
#
#   artist_location  artist_name             song_id                title  \
# 0                  Line Renaud  SOUPIRU12A6D4FA1E1  Der Kleine Dompfaff
#
#     duration  year
# 0  152.92036     0

# %%
song_data = file[['song_id', 'title', 'artist_id', 'year', 'duration']]
song_data.values
# Out:
# array([['SOUPIRU12A6D4FA1E1', 'Der Kleine Dompfaff',
#         'ARJIE2Y1187B994AB7', 0, 152.92036]], dtype=object)
